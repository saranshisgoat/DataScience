# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler
from sklearn.naive_bayes import GaussianNB
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, cross_validate
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, StackingClassifier, AdaBoostClassifier, HistGradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import warnings
sns.set_palette("rocket")
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r'C:\Users\smaha\Downloads\Creditcard_data (1).csv')
data.drop(["Time"],axis=1,inplace=True)

X = data.drop(["Class"],axis=1)
y = data["Class"]

data.head(20)
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# 0  -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2  -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3  -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4  -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5  -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7  -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8  -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9  -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
# 10  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152 -1.423236
# 11  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027  0.470455
# 12  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230 -0.689405
# 13  1.069374  0.287722  0.828613  2.712520 -0.178398  0.337544 -0.096717
# 14 -2.791855 -0.327771  1.641750  1.767473 -0.136588  0.807596 -0.422911
# 15 -0.752417  0.345485  2.057323 -1.468643 -1.158394 -0.077850 -0.608581
# 16  1.103215 -0.040296  1.267332  1.289091 -0.735997  0.288069 -0.586057
# 17 -0.436905  0.918966  0.924591 -0.727219  0.915679 -0.127867  0.707642
# 18 -5.401258 -5.450148  1.186305  1.736239  3.049106 -1.763406 -1.559738
# 19  1.492936 -1.029346  0.454795 -1.438026 -1.555434 -0.720961 -1.080664
#
#           V8        V9       V10  ...       V21       V22       V23       V24  \
# 0   0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1   0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2   0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3   0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
# 5   0.260314 -0.568671 -0.371407  ... -0.208254 -0.559825 -0.026398 -0.371427
# 6   0.081213  0.464960 -0.099254  ... -0.167716 -0.270710 -0.154104 -0.780055
# 7  -3.807864  0.615375  1.249376  ...  1.943465 -1.015455  0.057504 -0.649709
# 8   0.851084 -0.392048 -0.410430  ... -0.073425 -0.268092 -0.204233  1.011592
# 9   0.069539 -0.736727 -0.366846  ... -0.246914 -0.633753 -0.120794 -0.385050
# 10  0.048456 -1.720408  1.626659  ... -0.009302  0.313894  0.027740  0.500512
# 11  0.538247 -0.558895  0.309755  ...  0.049924  0.238422  0.009130  0.996710
# 12 -0.227487 -2.094011  1.323729  ... -0.231809 -0.483285  0.084668  0.392831
# 13  0.115982 -0.221083  0.460230  ... -0.036876  0.074412 -0.071407  0.104744
# 14 -1.907107  0.755713  1.151087  ...  1.151663  0.222182  1.020586  0.028317
# 15  0.003603 -0.436167  0.747731  ...  0.499625  1.353650 -0.256573 -0.065084
# 16  0.189380  0.782333 -0.267975  ... -0.024612  0.196002  0.013802  0.103758
# 17  0.087962 -0.665271 -0.737980  ... -0.194796 -0.672638 -0.156858 -0.888386
# 18  0.160842  1.233090  0.345173  ... -0.503600  0.984460  2.458589  0.042119
# 19 -0.053127 -1.978682  1.638076  ... -0.177650 -0.175074  0.040002  0.295814
#
#          V25       V26       V27       V28  Amount  Class
# 0   0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1   0.167170  0.125895 -0.008983  0.014724    2.69      1
# 2  -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3   0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4  -0.206010  0.502292  0.219422  0.215153   69.99      0
# 5  -0.232794  0.105915  0.253844  0.081080    3.67      0
# 6   0.750137 -0.257237  0.034507  0.005168    4.99      0
# 7  -0.415267 -0.051634 -1.206921 -1.085339   40.80      0
# 8   0.373205 -0.384157  0.011747  0.142404   93.20      0
# 9  -0.069733  0.094199  0.246219  0.083076    3.68      0
# 10  0.251367 -0.129478  0.042850  0.016253    7.80      0
# 11 -0.767315 -0.492208  0.042472 -0.054337    9.99      0
# 12  0.161135 -0.354990  0.026416  0.042422  121.50      0
# 13  0.548265  0.104094  0.021491  0.021293   27.50      0
# 14 -0.232746 -0.235557 -0.164778 -0.030154   58.80      0
# 15 -0.039124 -0.087086 -0.180998  0.129394   15.99      0
# 16  0.364298 -0.382261  0.092809  0.037051   12.99      0
# 17 -0.342413 -0.049027  0.079692  0.131024    0.89      0
# 18 -0.481631 -0.621272  0.392053  0.949594   46.80      0
# 19  0.332931 -0.220385  0.022298  0.007602    5.00      0
#
# [20 rows x 30 columns]

# %%
sns.countplot(x=y);

# %%
X_over1, y_over1 = RandomOverSampler().fit_resample(X, y)
X_over2, y_over2 = SMOTE().fit_resample(X, y)
X_over3, y_over3 = ADASYN().fit_resample(X, y)
X_under, y_under = RandomUnderSampler().fit_resample(X, y)

plt.subplots(1, 3, figsize=(15, 4))

plt.subplot(1, 3, 1)
sns.countplot(x=y)
plt.title("Original Distribution")

plt.subplot(1, 3, 2)
sns.countplot(x=y_over1)
plt.title("Random Oversampled Distribution")

plt.subplot(1, 3, 3)
sns.countplot(x=y_under)
plt.title("Random Undersampled Distribution")

plt.show()

# %%
rf = RandomForestClassifier()
knn = KNeighborsClassifier()
nbc = GaussianNB()
dt = DecisionTreeClassifier()
lgbm = LGBMClassifier(verbose=-1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

rf.fit(X_train, y_train)
knn.fit(X_train, y_train)
nbc.fit(X_train, y_train)
dt.fit(X_train, y_train)
lgbm.fit(X_train, y_train)

print("\n", "-"*30)
print("Accuracy of RF Original:", accuracy_score(rf.predict(X_test), y_test))
print("Accuracy of KNN Original:", accuracy_score(knn.predict(X_test), y_test))
print("Accuracy of NBC Original:", accuracy_score(nbc.predict(X_test), y_test))
print("Accuracy of DT Original:", accuracy_score(dt.predict(X_test), y_test))
print("Accuracy of LGBM Original:", accuracy_score(lgbm.predict(X_test), y_test))

X_train, X_test, y_train, y_test = train_test_split(X_over1, y_over1, test_size=0.3)

rf.fit(X_train, y_train)
knn.fit(X_train, y_train)
nbc.fit(X_train, y_train)
dt.fit(X_train, y_train)
lgbm.fit(X_train, y_train)

print("\n", "-"*30)
print("Accuracy of RF RANDOM OVERSAMPLED:", accuracy_score(rf.predict(X_test), y_test))
print("Accuracy of KNN RANDOM OVERSAMPLED:", accuracy_score(knn.predict(X_test), y_test))
print("Accuracy of NBC RANDOM OVERSAMPLED:", accuracy_score(nbc.predict(X_test), y_test))
print("Accuracy of DT RANDOM OVERSAMPLED:", accuracy_score(dt.predict(X_test), y_test))
print("Accuracy of LGBM RANDOM OVERSAMPLED:", accuracy_score(lgbm.predict(X_test), y_test))

X_train, X_test, y_train, y_test = train_test_split(X_over2, y_over2, test_size=0.3)

rf.fit(X_train, y_train)
knn.fit(X_train, y_train)
nbc.fit(X_train, y_train)
dt.fit(X_train, y_train)
lgbm.fit(X_train, y_train)

print("\n", "-"*30)
print("Accuracy of RF SMOTE OVERSAMPLED:", accuracy_score(rf.predict(X_test), y_test))
print("Accuracy of KNN SMOTE OVERSAMPLED:", accuracy_score(knn.predict(X_test), y_test))
print("Accuracy of NBC SMOTE OVERSAMPLED:", accuracy_score(nbc.predict(X_test), y_test))
print("Accuracy of DT SMOTE OVERSAMPLED:", accuracy_score(dt.predict(X_test), y_test))
print("Accuracy of LGBM SMOTE OVERSAMPLED:", accuracy_score(lgbm.predict(X_test), y_test))

X_train, X_test, y_train, y_test = train_test_split(X_over3, y_over3, test_size=0.3)

rf.fit(X_train, y_train)
knn.fit(X_train, y_train)
nbc.fit(X_train, y_train)
dt.fit(X_train, y_train)
lgbm.fit(X_train, y_train)

print("\n", "-"*30)
print("Accuracy of RF ADASYN OVERSAMPLED:", accuracy_score(rf.predict(X_test), y_test))
print("Accuracy of KNN ADASYN OVERSAMPLED:", accuracy_score(knn.predict(X_test), y_test))
print("Accuracy of NBC ADASYN OVERSAMPLED:", accuracy_score(nbc.predict(X_test), y_test))
print("Accuracy of DT ADASYN OVERSAMPLED:", accuracy_score(dt.predict(X_test), y_test))
print("Accuracy of LGBM ADASYN OVERSAMPLED:", accuracy_score(lgbm.predict(X_test), y_test))

X_train, X_test, y_train, y_test = train_test_split(X_under, y_under, test_size=0.3)

rf.fit(X_train, y_train)
knn.fit(X_train, y_train)
nbc.fit(X_train, y_train)
dt.fit(X_train, y_train)
lgbm.fit(X_train, y_train)

print("\n", "-"*30)
print("Accuracy of RF RANDOM UNDERSAMPLED:", accuracy_score(rf.predict(X_test), y_test))
print("Accuracy of KNN RANDOM UNDERSAMPLED:", accuracy_score(knn.predict(X_test), y_test))
print("Accuracy of NBC RANDOM UNDERSAMPLED:", accuracy_score(nbc.predict(X_test), y_test))
print("Accuracy of DT RANDOM UNDERSAMPLED:", accuracy_score(dt.predict(X_test), y_test))
print("Accuracy of LGBM RANDOM UNDERSAMPLED:", accuracy_score(lgbm.predict(X_test), y_test))
# Out:
#  ------------------------------
# Accuracy of RF Original: 0.9870689655172413
# Accuracy of KNN Original: 0.9870689655172413
# Accuracy of NBC Original: 0.9612068965517241
# Accuracy of DT Original: 0.9741379310344828
# Accuracy of LGBM Original: 0.9870689655172413
#
#  ------------------------------
# Accuracy of RF RANDOM OVERSAMPLED: 1.0
# Accuracy of KNN RANDOM OVERSAMPLED: 0.9759825327510917
# Accuracy of NBC RANDOM OVERSAMPLED: 0.7117903930131004
# Accuracy of DT RANDOM OVERSAMPLED: 0.9956331877729258
# Accuracy of LGBM RANDOM OVERSAMPLED: 1.0
#
#  ------------------------------
# Accuracy of RF SMOTE OVERSAMPLED: 0.9978165938864629
# Accuracy of KNN SMOTE OVERSAMPLED: 0.9104803493449781
# Accuracy of NBC SMOTE OVERSAMPLED: 0.7445414847161572
# Accuracy of DT SMOTE OVERSAMPLED: 0.9847161572052402
# Accuracy of LGBM SMOTE OVERSAMPLED: 0.9956331877729258
#
#  ------------------------------
# Accuracy of RF ADASYN OVERSAMPLED: 0.9956427015250545
# Accuracy of KNN ADASYN OVERSAMPLED: 0.9259259259259259
# Accuracy of NBC ADASYN OVERSAMPLED: 0.7494553376906318
# Accuracy of DT ADASYN OVERSAMPLED: 0.9738562091503268
# Accuracy of LGBM ADASYN OVERSAMPLED: 0.9912854030501089
#
#  ------------------------------
# Accuracy of RF RANDOM UNDERSAMPLED: 0.5
# Accuracy of KNN RANDOM UNDERSAMPLED: 0.5
# Accuracy of NBC RANDOM UNDERSAMPLED: 0.3333333333333333
# Accuracy of DT RANDOM UNDERSAMPLED: 0.3333333333333333
# Accuracy of LGBM RANDOM UNDERSAMPLED: 0.5
